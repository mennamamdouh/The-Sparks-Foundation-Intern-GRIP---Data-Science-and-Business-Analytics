# %% [markdown]
# # **Task 1 - Linear Regression**

# %%
# Importing all needed libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Reading data from remote link
url = "http://bit.ly/w-data"
our_data = pd.read_csv(url)
print("Data imported successfully")
# Out:
# Data imported successfully

# %%
# Printing our data
our_data
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
# Plotting the distribution of scores
our_data.plot(x='Hours', y='Scores', style='o')
plt.title('Hours vs. Percentages')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Score')
plt.show()

# %% [markdown]
# NOTE: There's a positive linear relation between the number of hours studied and percentage of score

# %% [markdown]
# # Preparing and Training the model

# %%
# Dividing the data into inputs and outputs
x = our_data.iloc[:, :-1].values
y = our_data.iloc[:, 1].values

# %%
# Printing the inputs (the hours studied)
print("Inputs are:", x)

# %%
# Printing the outputs (the scores)
print("Outputs are:",y)

# %%
# Splitting the data into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
# Training the model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)

# %%
# Plotting the regression line
line = regressor.coef_*x+regressor.intercept_

# Plotting for the test data
plt.scatter(x, y)
plt.plot(x, line)
plt.show()

# %%
# Making the predections of the test data
Y_pred = regressor.predict(X_test)

# Comparison between the actual data vs. the predicted data
dataFrame = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})

# %%
# Printing the Comparison
dataFrame
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %% [markdown]
# # Testing our data

# %%
hours = [[9.25]]
own_pred = regressor.predict(hours)
print("The predicted score = {}".format(own_pred[0]))
# Out:
# The predicted score = 93.69173248737539

# %% [markdown]
# # Evaluating the model

# %%
# Evaluating the model using the mean absolute error
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, y_pred))
# Out:
# Mean Absolute Error: 4.183859899002982
